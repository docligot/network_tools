# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
edges = pd.read_csv('edges_sample.csv', header=0, encoding = "ISO-8859-1")

# %%
edges
# Out:
#                                                  from  \
# 0                                    Docteur Résimont
# 1                                      Guns & Country
# 2                        Healthy Earth - Healthy Home
# 3                        Healthy Earth - Healthy Home
# 4   Uniting Healthcare Professionals Against Manda...
# 5   Bristol Residents For SAFE Technology - Take A...
# 6                                      Guns & Country
# 7                        Healthy Earth - Healthy Home
# 8          Bought   The Movie    Truth about Vaccines
# 9                                  Psychedelics Today
# 10                       Healthy Earth - Healthy Home
# 11                        Doug's Compounding Pharmacy
# 12                                   Docteur Résimont
# 13  Uniting Healthcare Professionals Against Manda...
# 14                        Doug's Compounding Pharmacy
# 15                                    HEAL California
# 16  Bristol Residents For SAFE Technology - Take A...
# 17         Bought   The Movie    Truth about Vaccines
# 18                                     Guns & Country
# 19                                    HEAL California
# 20  Uniting Healthcare Professionals Against Manda...
# 21         Bought   The Movie    Truth about Vaccines
# 22  Bristol Residents For SAFE Technology - Take A...
# 23  Uniting Healthcare Professionals Against Manda...
#
#                                                    to
# 0            JABS: Justice  Awareness & Basic Support
# 1   Bristol Residents For SAFE Technology - Take A...
# 2            JABS: Justice  Awareness & Basic Support
# 3                                        Patel Prasad
# 4   Bristol Residents For SAFE Technology - Take A...
# 5                     Parents Against Wi-Fi in School
# 6                                      Ronald Bernard
# 7                                           Blind Joe
# 8   Bristol Residents For SAFE Technology - Take A...
# 9                                  Psychedelics Today
# 10         Bought   The Movie    Truth about Vaccines
# 11                                          Blind Joe
# 12                                  beforeitsnews.com
# 13                    Parents Against Wi-Fi in School
# 14                                 Psychedelics Today
# 15              ?????? Hongkongese revolution channel
# 16                                  beforeitsnews.com
# 17                       Healthy Earth - Healthy Home
# 18         Bought   The Movie    Truth about Vaccines
# 19                                       Patel Prasad
# 20         Bought   The Movie    Truth about Vaccines
# 21                                  beforeitsnews.com
# 22                    Parents Against Wi-Fi in School
# 23           JABS: Justice  Awareness & Basic Support

# %%
G = nx.from_pandas_edgelist(edges, source = 'from', target = 'to')
D = nx.from_pandas_edgelist(edges, source = 'from', target = 'to', create_using=nx.DiGraph())

# %%
#nx.draw(G, font_color="red", node_color="lime", with_labels=True)

nx.draw(G, with_labels=True)
plt.show()

# %%
nx.draw(D, with_labels=True)
plt.show()

# %%
nx.draw_circular(G, with_labels=True)
plt.show()

# %%
nx.draw_spectral(G, with_labels=True)
plt.show()

# %%
nx.draw_planar(G, with_labels=True)
plt.show()

# %%
nx.draw_spring(G, with_labels=True)
plt.show()

# %%
nx.draw_shell(G, with_labels=True)
plt.show()

# %%
nx.draw_random(G, with_labels=True)
plt.show()

# %%
pd.DataFrame(G.edges)
# Out:
#                                                     0  \
# 0                                    Docteur Résimont
# 1                                    Docteur Résimont
# 2            JABS: Justice  Awareness & Basic Support
# 3            JABS: Justice  Awareness & Basic Support
# 4                                      Guns & Country
# 5                                      Guns & Country
# 6                                      Guns & Country
# 7   Bristol Residents For SAFE Technology - Take A...
# 8   Bristol Residents For SAFE Technology - Take A...
# 9   Bristol Residents For SAFE Technology - Take A...
# 10  Bristol Residents For SAFE Technology - Take A...
# 11                       Healthy Earth - Healthy Home
# 12                       Healthy Earth - Healthy Home
# 13                       Healthy Earth - Healthy Home
# 14                                       Patel Prasad
# 15  Uniting Healthcare Professionals Against Manda...
# 16  Uniting Healthcare Professionals Against Manda...
# 17                                          Blind Joe
# 18         Bought   The Movie    Truth about Vaccines
# 19                                 Psychedelics Today
# 20                                 Psychedelics Today
# 21                                    HEAL California
#
#                                                     1
# 0            JABS: Justice  Awareness & Basic Support
# 1                                   beforeitsnews.com
# 2                        Healthy Earth - Healthy Home
# 3   Uniting Healthcare Professionals Against Manda...
# 4   Bristol Residents For SAFE Technology - Take A...
# 5                                      Ronald Bernard
# 6          Bought   The Movie    Truth about Vaccines
# 7   Uniting Healthcare Professionals Against Manda...
# 8                     Parents Against Wi-Fi in School
# 9          Bought   The Movie    Truth about Vaccines
# 10                                  beforeitsnews.com
# 11                                       Patel Prasad
# 12                                          Blind Joe
# 13         Bought   The Movie    Truth about Vaccines
# 14                                    HEAL California
# 15                    Parents Against Wi-Fi in School
# 16         Bought   The Movie    Truth about Vaccines
# 17                        Doug's Compounding Pharmacy
# 18                                  beforeitsnews.com
# 19                                 Psychedelics Today
# 20                        Doug's Compounding Pharmacy
# 21              ?????? Hongkongese revolution channel

# %%
pd.DataFrame(G.nodes)
# Out:
#                                                     0
# 0                                    Docteur Résimont
# 1            JABS: Justice  Awareness & Basic Support
# 2                                      Guns & Country
# 3   Bristol Residents For SAFE Technology - Take A...
# 4                        Healthy Earth - Healthy Home
# 5                                        Patel Prasad
# 6   Uniting Healthcare Professionals Against Manda...
# 7                     Parents Against Wi-Fi in School
# 8                                      Ronald Bernard
# 9                                           Blind Joe
# 10         Bought   The Movie    Truth about Vaccines
# 11                                 Psychedelics Today
# 12                        Doug's Compounding Pharmacy
# 13                                  beforeitsnews.com
# 14                                    HEAL California
# 15              ?????? Hongkongese revolution channel

# %%
degrees = [val for (node, val) in G.degree()]
degrees
# Out:
# [2, 3, 3, 5, 4, 2, 4, 2, 1, 2, 5, 3, 2, 3, 2, 1]

# %%
in_degrees = [val for (node, val) in D.in_degree()]
in_degrees
# Out:
# [0, 3, 0, 3, 1, 2, 0, 2, 1, 2, 3, 2, 0, 3, 0, 1]

# %%
out_degrees = [val for (node, val) in D.out_degree()]
out_degrees
# Out:
# [2, 0, 3, 2, 4, 0, 4, 0, 0, 0, 3, 1, 2, 0, 2, 0]

# %%
closeness_centrality = nx.closeness_centrality(G)
pd.DataFrame(list(closeness_centrality.items()))
# Out:
#                                                     0         1
# 0                                    Docteur Résimont  0.340909
# 1            JABS: Justice  Awareness & Basic Support  0.416667
# 2                                      Guns & Country  0.365854
# 3   Bristol Residents For SAFE Technology - Take A...  0.405405
# 4                        Healthy Earth - Healthy Home  0.500000
# 5                                        Patel Prasad  0.375000
# 6   Uniting Healthcare Professionals Against Manda...  0.384615
# 7                     Parents Against Wi-Fi in School  0.306122
# 8                                      Ronald Bernard  0.272727
# 9                                           Blind Joe  0.375000
# 10         Bought   The Movie    Truth about Vaccines  0.483871
# 11                                 Psychedelics Today  0.227273
# 12                        Doug's Compounding Pharmacy  0.288462
# 13                                  beforeitsnews.com  0.375000
# 14                                    HEAL California  0.288462
# 15              ?????? Hongkongese revolution channel  0.227273

# %%
betweeness_centrality = nx.betweenness_centrality(G, normalized = True, endpoints = False)
pd.DataFrame(list(betweeness_centrality.items()))
# Out:
#                                                     0         1
# 0                                    Docteur Résimont  0.009524
# 1            JABS: Justice  Awareness & Basic Support  0.136508
# 2                                      Guns & Country  0.133333
# 3   Bristol Residents For SAFE Technology - Take A...  0.100000
# 4                        Healthy Earth - Healthy Home  0.611111
# 5                                        Patel Prasad  0.247619
# 6   Uniting Healthcare Professionals Against Manda...  0.090476
# 7                     Parents Against Wi-Fi in School  0.000000
# 8                                      Ronald Bernard  0.000000
# 9                                           Blind Joe  0.247619
# 10         Bought   The Movie    Truth about Vaccines  0.390476
# 11                                 Psychedelics Today  0.000000
# 12                        Doug's Compounding Pharmacy  0.133333
# 13                                  beforeitsnews.com  0.042857
# 14                                    HEAL California  0.133333
# 15              ?????? Hongkongese revolution channel  0.000000

# %%
page_rank = nx.pagerank(G, alpha=0.8)
pd.DataFrame(list(page_rank.items()))
# Out:
#                                                     0         1
# 0                                    Docteur Résimont  0.045909
# 1            JABS: Justice  Awareness & Basic Support  0.064067
# 2                                      Guns & Country  0.067184
# 3   Bristol Residents For SAFE Technology - Take A...  0.094614
# 4                        Healthy Earth - Healthy Home  0.088858
# 5                                        Patel Prasad  0.056893
# 6   Uniting Healthcare Professionals Against Manda...  0.077165
# 7                     Parents Against Wi-Fi in School  0.043071
# 8                                      Ronald Bernard  0.030416
# 9                                           Blind Joe  0.053254
# 10         Bought   The Movie    Truth about Vaccines  0.095082
# 11                                 Psychedelics Today  0.059138
# 12                        Doug's Compounding Pharmacy  0.057457
# 13                                  beforeitsnews.com  0.061215
# 14                                    HEAL California  0.066556
# 15              ?????? Hongkongese revolution channel  0.039121
